# %%
train_dir=r'C:\Users\bharath\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train'
test_dir=r'C:\Users\bharath\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\test'

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'C:\Users\bharath\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit.H5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model = load_model("fruit.H5")

# %%
img=image.load_img(r"C:\Users\bharath\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30ff1b97-0850-4224-a176-bfa284d92a24___JR_FrgE.S 2940.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img=image.load_img(r"C:\Users\bharath\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30ff1b97-0850-4224-a176-bfa284d92a24___JR_FrgE.S 2940.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple__Black_rot', 'Apple_healthy', 'Corn(maize)__healthy', 'Corn(maize)__Northern_Leaf_Blight', 'Peach_Bacterial_spot', 'Peach__healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 3s 3s/step
# 'Apple__Black_rot'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 5s 68ms/step - loss: 824.0302 - accuracy: 0.7030
# [824.0302124023438, 0.703000009059906]
